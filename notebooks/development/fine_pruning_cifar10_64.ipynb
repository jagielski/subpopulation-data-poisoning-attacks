# %% [markdown]
# # Fine pruning defense
#
# This notebook will contain code to run the fine prining defense https://link.springer.com/chapter/10.1007/978-3-030-00470-5_13

# %%
import os

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.vgg16 import VGG16

from kerassurgeon import Surgeon
from kerassurgeon import identify
from kerassurgeon.operations import delete_channels

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data

# %%
trn_x = np.load('../../64/trn_x.npy')
trn_y = np.load('../../64/trn_y.npy')
pt_x = np.load('../../64/pt_x.npy')
pt_y = np.load('../../64/pt_y.npy')
p_x = np.load('../../64/p_x.npy')
p_y = np.load('../../64/p_y.npy')
tst_x = np.load('../../64/tst_x.npy')
tst_y = np.load('../../64/tst_y.npy')
valid_x = np.load('../../64/valid_x.npy')
valid_y = np.load('../../64/valid_y.npy')

valid_x, ft_x, valid_y, ft_y = train_test_split(valid_x, valid_y, test_size=0.1, random_state=42)

print(
    '\ntrain',
    trn_x.shape,
    trn_y.shape,
    '\npt',
    pt_x.shape,
    pt_y.shape,
    '\np',
    p_x.shape,
    p_y.shape,
    '\ntst',
    tst_x.shape,
    tst_y.shape,
    '\nft',
    ft_x.shape,
    ft_y.shape,
    '\nvalid',
    valid_x.shape,
    valid_y.shape,
)
# Out:
# train (7144, 100, 100, 3) (7144, 2)
# pt (37, 100, 100, 3) (37, 2)
# p (144, 100, 100, 3) (144, 2)
# tst (6054, 100, 100, 3) (6054, 2)
# ft (700, 100, 100, 3) (700, 2)
# valid (6300, 100, 100, 3) (6300, 2)

# %% [markdown]
# ## Model
#
# Placeholder

# %%
model = keras.models.load_model('../../64/model')

# %%
score = model.evaluate(tst_x, tst_y, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
original_acc = score[1]
# Out:
# Test loss: 0.4330230951309204
# Test accuracy: 0.8386191129684448

# %%
score_pt = model.evaluate(pt_x, pt_y, verbose=0)
print("pt loss:", score_pt[0])
print("pt accuracy:", score_pt[1])
# Out:
# pt loss: 0.5020550489425659
# pt accuracy: 0.7567567825317383

# %%
print(model.count_params())
print(model.summary())
# Out:
# 14715714
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 100, 100, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 100, 100, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 50, 50, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 50, 50, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 50, 50, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 25, 25, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 25, 25, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 1026
# =================================================================
# Total params: 14,715,714
# Trainable params: 14,715,714
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Pruning

# %%
stop_cond = False
cur_idx = 0
tgt_layer = 'block5_conv3'

target_layer = model.get_layer(tgt_layer)
apoz = identify.get_apoz(model, target_layer, tst_x)
print('Neurons in layer', len(apoz))  
    
high_apoz_channels = identify.high_apoz(apoz, "both", cutoff_absolute=0.55)
if len(high_apoz_channels) == 0: 
    print('Zero channels found')
        
while not stop_cond:
    target_layer = model.get_layer(tgt_layer)  
    print('Neurons to prune', high_apoz_channels[cur_idx])
    
    model = delete_channels(model, target_layer, [high_apoz_channels[cur_idx],])
    model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    score = model.evaluate(tst_x, tst_y, verbose=0)

    print('Number of neurons pruned:', cur_idx)
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])

    cur_idx += 1
    if original_acc - score[1] > .04:
        stop_cond = True
#     keras.backend.clear_session()
        
print('\nFINAL')
print('Number of weights set to 0:', cur_idx)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Neurons in layer 512
# Neurons to prune 0
# Deleting 1/512 channels from layer: block5_conv3
# Number of neurons pruned: 0
# Test loss: 0.4329279363155365
# Test accuracy: 0.8387842774391174
# Neurons to prune 1
# Deleting 1/511 channels from layer: block5_conv3
# Number of neurons pruned: 1
# Test loss: 0.4328213334083557
# Test accuracy: 0.8386191129684448
# Neurons to prune 2
# Deleting 1/510 channels from layer: block5_conv3
# Number of neurons pruned: 2
# Test loss: 0.43239256739616394
# Test accuracy: 0.8391146063804626
# Neurons to prune 3
# Deleting 1/509 channels from layer: block5_conv3
# Number of neurons pruned: 3
# Test loss: 0.43240341544151306
# Test accuracy: 0.8391146063804626
# Neurons to prune 4
# Deleting 1/508 channels from layer: block5_conv3
# Number of neurons pruned: 4
# Test loss: 0.4343329966068268
# Test accuracy: 0.83894944190979
# Neurons to prune 5
# Deleting 1/507 channels from layer: block5_conv3
# Number of neurons pruned: 5
# Test loss: 0.4339306950569153
# Test accuracy: 0.8404361009597778
# Neurons to prune 6
# Deleting 1/506 channels from layer: block5_conv3
# Number of neurons pruned: 6
# Test loss: 0.43358734250068665
# Test accuracy: 0.8437396883964539
# Neurons to prune 7
# Deleting 1/505 channels from layer: block5_conv3
# Number of neurons pruned: 7
# Test loss: 0.4335874915122986
# Test accuracy: 0.8437396883964539
# Neurons to prune 8
# Deleting 1/504 channels from layer: block5_conv3
# Number of neurons pruned: 8
# Test loss: 0.43357905745506287
# Test accuracy: 0.8437396883964539
# Neurons to prune 9
# Deleting 1/503 channels from layer: block5_conv3
# Number of neurons pruned: 9
# Test loss: 0.43358469009399414
# Test accuracy: 0.8437396883964539
# Neurons to prune 10
# Deleting 1/502 channels from layer: block5_conv3
# Number of neurons pruned: 10
# Test loss: 0.43358564376831055
# Test accuracy: 0.8437396883964539
# Neurons to prune 11
# Deleting 1/501 channels from layer: block5_conv3
# Number of neurons pruned: 11
# Test loss: 0.4335874915122986
# Test accuracy: 0.8440700173377991
# Neurons to prune 12
# Deleting 1/500 channels from layer: block5_conv3
# Number of neurons pruned: 12
# Test loss: 0.43357327580451965
# Test accuracy: 0.8440700173377991
# Neurons to prune 13
# Deleting 1/499 channels from layer: block5_conv3
# Number of neurons pruned: 13
# Test loss: 0.4330398142337799
# Test accuracy: 0.8427485823631287
# Neurons to prune 14
# Deleting 1/498 channels from layer: block5_conv3
# Number of neurons pruned: 14
# Test loss: 0.4330460727214813
# Test accuracy: 0.8427485823631287
# Neurons to prune 15
# Deleting 1/497 channels from layer: block5_conv3
# Number of neurons pruned: 15
# Test loss: 0.43304628133773804
# Test accuracy: 0.8434092998504639
# Neurons to prune 16
# Deleting 1/496 channels from layer: block5_conv3
# Number of neurons pruned: 16
# Test loss: 0.43302419781684875
# Test accuracy: 0.8435745239257812
# Neurons to prune 17
# Deleting 1/495 channels from layer: block5_conv3
# Number of neurons pruned: 17
# Test loss: 0.43313685059547424
# Test accuracy: 0.8427485823631287
# Neurons to prune 18
# Deleting 1/494 channels from layer: block5_conv3
# Number of neurons pruned: 18
# Test loss: 0.43301162123680115
# Test accuracy: 0.8427485823631287
# Neurons to prune 19
# Deleting 1/493 channels from layer: block5_conv3
# Number of neurons pruned: 19
# Test loss: 0.43309804797172546
# Test accuracy: 0.8427485823631287
# Neurons to prune 20
# Deleting 1/492 channels from layer: block5_conv3
# Number of neurons pruned: 20
# Test loss: 0.43309807777404785
# Test accuracy: 0.8427485823631287
# Neurons to prune 21
# Deleting 1/491 channels from layer: block5_conv3
# Number of neurons pruned: 21
# Test loss: 0.4331017732620239
# Test accuracy: 0.8422530293464661
# Neurons to prune 22
# Deleting 1/490 channels from layer: block5_conv3
# Number of neurons pruned: 22
# Test loss: 0.43312159180641174
# Test accuracy: 0.8429137468338013
# Neurons to prune 23
# Deleting 1/489 channels from layer: block5_conv3
# Number of neurons pruned: 23
# Test loss: 0.43310636281967163
# Test accuracy: 0.8432441353797913
# Neurons to prune 24
# Deleting 1/488 channels from layer: block5_conv3
# Number of neurons pruned: 24
# Test loss: 0.4331004023551941
# Test accuracy: 0.8434092998504639
# Neurons to prune 25
# Deleting 1/487 channels from layer: block5_conv3
# Number of neurons pruned: 25
# Test loss: 0.43312132358551025
# Test accuracy: 0.842583417892456
# Neurons to prune 26
# Deleting 1/486 channels from layer: block5_conv3
# Number of neurons pruned: 26
# Test loss: 0.43314552307128906
# Test accuracy: 0.842583417892456
# Neurons to prune 27
# Deleting 1/485 channels from layer: block5_conv3
# Number of neurons pruned: 27
# Test loss: 0.43314066529273987
# Test accuracy: 0.842583417892456
# Neurons to prune 28
# Deleting 1/484 channels from layer: block5_conv3
# Number of neurons pruned: 28
# Test loss: 0.4330342411994934
# Test accuracy: 0.8422530293464661
# Neurons to prune 29
# Deleting 1/483 channels from layer: block5_conv3
# Number of neurons pruned: 29
# Test loss: 0.43303167819976807
# Test accuracy: 0.8422530293464661
# Neurons to prune 30
# Deleting 1/482 channels from layer: block5_conv3
# Number of neurons pruned: 30
# Test loss: 0.43321463465690613
# Test accuracy: 0.8420878648757935
# Neurons to prune 31
# Deleting 1/481 channels from layer: block5_conv3
# Number of neurons pruned: 31
# Test loss: 0.43228697776794434
# Test accuracy: 0.8415923118591309
# Neurons to prune 32
# Deleting 1/480 channels from layer: block5_conv3
# Number of neurons pruned: 32
# Test loss: 0.4324454367160797
# Test accuracy: 0.8417575359344482
# Neurons to prune 33
# Deleting 1/479 channels from layer: block5_conv3
# Number of neurons pruned: 33
# Test loss: 0.4322935938835144
# Test accuracy: 0.8434092998504639
# Neurons to prune 34
# Deleting 1/478 channels from layer: block5_conv3
# Number of neurons pruned: 34
# Test loss: 0.4322950541973114
# Test accuracy: 0.8434092998504639
# Neurons to prune 35
# Deleting 1/477 channels from layer: block5_conv3
# Number of neurons pruned: 35
# Test loss: 0.43249183893203735
# Test accuracy: 0.8447307348251343
# Neurons to prune 36
# Deleting 1/476 channels from layer: block5_conv3
# Number of neurons pruned: 36
# Test loss: 0.4332086741924286
# Test accuracy: 0.8424182534217834
# Neurons to prune 37
# Deleting 1/475 channels from layer: block5_conv3
# Number of neurons pruned: 37
# Test loss: 0.43322375416755676
# Test accuracy: 0.8424182534217834
# Neurons to prune 38
# Deleting 1/474 channels from layer: block5_conv3
# Number of neurons pruned: 38
# Test loss: 0.4331212043762207
# Test accuracy: 0.8422530293464661
# Neurons to prune 39
# Deleting 1/473 channels from layer: block5_conv3
# Number of neurons pruned: 39
# Test loss: 0.43312153220176697
# Test accuracy: 0.8422530293464661
# Neurons to prune 40
# Deleting 1/472 channels from layer: block5_conv3
# Number of neurons pruned: 40
# Test loss: 0.43309763073921204
# Test accuracy: 0.8422530293464661
# Neurons to prune 41
# Deleting 1/471 channels from layer: block5_conv3
# Number of neurons pruned: 41
# Test loss: 0.4332418441772461
# Test accuracy: 0.841096818447113
# Neurons to prune 42
# Deleting 1/470 channels from layer: block5_conv3
# Number of neurons pruned: 42
# Test loss: 0.43325141072273254
# Test accuracy: 0.8409315943717957
# Neurons to prune 43
# Deleting 1/469 channels from layer: block5_conv3
# Number of neurons pruned: 43
# Test loss: 0.4332278072834015
# Test accuracy: 0.8406012654304504
# Neurons to prune 44
# Deleting 1/468 channels from layer: block5_conv3
# Number of neurons pruned: 44
# Test loss: 0.43325963616371155
# Test accuracy: 0.840766429901123
# Neurons to prune 45
# Deleting 1/467 channels from layer: block5_conv3
# Number of neurons pruned: 45
# Test loss: 0.43325987458229065
# Test accuracy: 0.840766429901123
# Neurons to prune 46
# Deleting 1/466 channels from layer: block5_conv3
# Number of neurons pruned: 46
# Test loss: 0.43361178040504456
# Test accuracy: 0.8415923118591309
# Neurons to prune 47
# Deleting 1/465 channels from layer: block5_conv3
# Number of neurons pruned: 47
# Test loss: 0.4336150884628296
# Test accuracy: 0.8415923118591309
# Neurons to prune 48
# Deleting 1/464 channels from layer: block5_conv3
# Number of neurons pruned: 48
# Test loss: 0.43373847007751465
# Test accuracy: 0.8406012654304504
# Neurons to prune 49
# Deleting 1/463 channels from layer: block5_conv3
# Number of neurons pruned: 49
# Test loss: 0.4337845742702484
# Test accuracy: 0.841096818447113
# Neurons to prune 50
# Deleting 1/462 channels from layer: block5_conv3
# Number of neurons pruned: 50
# Test loss: 0.43393394351005554
# Test accuracy: 0.8412619829177856
# Neurons to prune 51
# Deleting 1/461 channels from layer: block5_conv3
# Number of neurons pruned: 51
# Test loss: 0.43389177322387695
# Test accuracy: 0.841096818447113
# Neurons to prune 52
# Deleting 1/460 channels from layer: block5_conv3
# Number of neurons pruned: 52
# Test loss: 0.43388622999191284
# Test accuracy: 0.840766429901123
# Neurons to prune 53
# Deleting 1/459 channels from layer: block5_conv3
# Number of neurons pruned: 53
# Test loss: 0.43391573429107666
# Test accuracy: 0.8401057124137878
# Neurons to prune 54
# Deleting 1/458 channels from layer: block5_conv3
# Number of neurons pruned: 54
# Test loss: 0.4345303475856781
# Test accuracy: 0.8396101593971252
# Neurons to prune 55
# Deleting 1/457 channels from layer: block5_conv3
# Number of neurons pruned: 55
# Test loss: 0.43490463495254517
# Test accuracy: 0.83927983045578
# Neurons to prune 57
# Deleting 1/456 channels from layer: block5_conv3
# Number of neurons pruned: 56
# Test loss: 0.43644073605537415
# Test accuracy: 0.8442352414131165
# Neurons to prune 58
# Deleting 1/455 channels from layer: block5_conv3
# Number of neurons pruned: 57
# Test loss: 0.43654099106788635
# Test accuracy: 0.8439048528671265
# Neurons to prune 59
# Deleting 1/454 channels from layer: block5_conv3
# Number of neurons pruned: 58
# Test loss: 0.4367223381996155
# Test accuracy: 0.8440700173377991
# Neurons to prune 60
# Deleting 1/453 channels from layer: block5_conv3
# Number of neurons pruned: 59
# Test loss: 0.436649888753891
# Test accuracy: 0.8445655703544617
# Neurons to prune 61
# Deleting 1/452 channels from layer: block5_conv3
# Number of neurons pruned: 60
# Test loss: 0.43759942054748535
# Test accuracy: 0.8440700173377991
# Neurons to prune 62
# Deleting 1/451 channels from layer: block5_conv3
# Number of neurons pruned: 61
# Test loss: 0.4383666217327118
# Test accuracy: 0.8409315943717957
# Neurons to prune 63
# Deleting 1/450 channels from layer: block5_conv3
# Number of neurons pruned: 62
# Test loss: 0.43731921911239624
# Test accuracy: 0.8434092998504639
# Neurons to prune 64
# Deleting 1/449 channels from layer: block5_conv3
# Number of neurons pruned: 63
# Test loss: 0.43732139468193054
# Test accuracy: 0.8434092998504639
# Neurons to prune 65
# Deleting 1/448 channels from layer: block5_conv3
# Number of neurons pruned: 64
# Test loss: 0.4373038411140442
# Test accuracy: 0.8437396883964539
# Neurons to prune 66
# Deleting 1/447 channels from layer: block5_conv3
# Number of neurons pruned: 65
# Test loss: 0.4374450445175171
# Test accuracy: 0.8434092998504639
# Neurons to prune 67
# Deleting 1/446 channels from layer: block5_conv3
# Number of neurons pruned: 66
# Test loss: 0.4373912513256073
# Test accuracy: 0.8440700173377991
# Neurons to prune 68
# Deleting 1/445 channels from layer: block5_conv3
# Number of neurons pruned: 67
# Test loss: 0.43739110231399536
# Test accuracy: 0.8440700173377991
# Neurons to prune 69
# Deleting 1/444 channels from layer: block5_conv3
# Number of neurons pruned: 68
# Test loss: 0.43695953488349915
# Test accuracy: 0.8439048528671265
# Neurons to prune 70
# Deleting 1/443 channels from layer: block5_conv3
# Number of neurons pruned: 69
# Test loss: 0.4368723928928375
# Test accuracy: 0.8444004058837891
# Neurons to prune 71
# Deleting 1/442 channels from layer: block5_conv3
# Number of neurons pruned: 70
# Test loss: 0.43686455488204956
# Test accuracy: 0.8444004058837891
# Neurons to prune 72
# Deleting 1/441 channels from layer: block5_conv3
# Number of neurons pruned: 71
# Test loss: 0.43686437606811523
# Test accuracy: 0.8444004058837891
# Neurons to prune 73
# Deleting 1/440 channels from layer: block5_conv3
# Number of neurons pruned: 72
# Test loss: 0.4368455708026886
# Test accuracy: 0.8444004058837891
# Neurons to prune 74
# Deleting 1/439 channels from layer: block5_conv3
# Number of neurons pruned: 73
# Test loss: 0.4367910921573639
# Test accuracy: 0.8442352414131165
# Neurons to prune 75
# Deleting 1/438 channels from layer: block5_conv3
# Number of neurons pruned: 74
# Test loss: 0.43674975633621216
# Test accuracy: 0.8439048528671265
# Neurons to prune 76
# Deleting 1/437 channels from layer: block5_conv3
# Number of neurons pruned: 75
# Test loss: 0.43676498532295227
# Test accuracy: 0.8439048528671265
# Neurons to prune 77
# Deleting 1/436 channels from layer: block5_conv3
# Number of neurons pruned: 76
# Test loss: 0.442397803068161
# Test accuracy: 0.8348199725151062
# Neurons to prune 78
# Deleting 1/435 channels from layer: block5_conv3
# Number of neurons pruned: 77
# Test loss: 0.4769505262374878
# Test accuracy: 0.805252730846405
# Neurons to prune 79
# Deleting 1/434 channels from layer: block5_conv3
# Number of neurons pruned: 78
# Test loss: 0.4760299324989319
# Test accuracy: 0.8062437772750854
# Neurons to prune 80
# Deleting 1/433 channels from layer: block5_conv3
# Number of neurons pruned: 79
# Test loss: 0.4771186113357544
# Test accuracy: 0.8060786128044128
# Neurons to prune 81
# Deleting 1/432 channels from layer: block5_conv3
# Number of neurons pruned: 80
# Test loss: 0.47665971517562866
# Test accuracy: 0.806739330291748
# Neurons to prune 82
# Deleting 1/431 channels from layer: block5_conv3
# Number of neurons pruned: 81
# Test loss: 0.4757826626300812
# Test accuracy: 0.8075652718544006
# Neurons to prune 83
# Deleting 1/430 channels from layer: block5_conv3
# Number of neurons pruned: 82
# Test loss: 0.4755536615848541
# Test accuracy: 0.8074000477790833
# Neurons to prune 84
# Deleting 1/429 channels from layer: block5_conv3
# Number of neurons pruned: 83
# Test loss: 0.47558730840682983
# Test accuracy: 0.8075652718544006
# Neurons to prune 85
# Deleting 1/428 channels from layer: block5_conv3
# Number of neurons pruned: 84
# Test loss: 0.4771023690700531
# Test accuracy: 0.8060786128044128
# Neurons to prune 86
# Deleting 1/427 channels from layer: block5_conv3
# Number of neurons pruned: 85
# Test loss: 0.4770984947681427
# Test accuracy: 0.8060786128044128
# Neurons to prune 87
# Deleting 1/426 channels from layer: block5_conv3
# Number of neurons pruned: 86
# Test loss: 0.4767947494983673
# Test accuracy: 0.8065741658210754
# Neurons to prune 88
# Deleting 1/425 channels from layer: block5_conv3
# Number of neurons pruned: 87
# Test loss: 0.4758031666278839
# Test accuracy: 0.8078956007957458
# Neurons to prune 89
# Deleting 1/424 channels from layer: block5_conv3
# Number of neurons pruned: 88
# Test loss: 0.4757729768753052
# Test accuracy: 0.8078956007957458
# Neurons to prune 90
# Deleting 1/423 channels from layer: block5_conv3
# Number of neurons pruned: 89
# Test loss: 0.4760761260986328
# Test accuracy: 0.8074000477790833
# Neurons to prune 91
# Deleting 1/422 channels from layer: block5_conv3
# Number of neurons pruned: 90
# Test loss: 0.476052850484848
# Test accuracy: 0.8074000477790833
# Neurons to prune 92
# Deleting 1/421 channels from layer: block5_conv3
# Number of neurons pruned: 91
# Test loss: 0.47616320848464966
# Test accuracy: 0.8074000477790833
# Neurons to prune 93
# Deleting 1/420 channels from layer: block5_conv3
# Number of neurons pruned: 92
# Test loss: 0.47633031010627747
# Test accuracy: 0.8072348833084106
# Neurons to prune 94
# Deleting 1/419 channels from layer: block5_conv3
# Number of neurons pruned: 93
# Test loss: 0.476295530796051
# Test accuracy: 0.8072348833084106
# Neurons to prune 95
# Deleting 1/418 channels from layer: block5_conv3
# Number of neurons pruned: 94
# Test loss: 0.4764454662799835
# Test accuracy: 0.8072348833084106
# Neurons to prune 96
# Deleting 1/417 channels from layer: block5_conv3
# Number of neurons pruned: 95
# Test loss: 0.47638779878616333
# Test accuracy: 0.8072348833084106
# Neurons to prune 97
# Deleting 1/416 channels from layer: block5_conv3
# Number of neurons pruned: 96
# Test loss: 0.4740206301212311
# Test accuracy: 0.808556318283081
# Neurons to prune 98
# Deleting 1/415 channels from layer: block5_conv3
# Number of neurons pruned: 97
# Test loss: 0.4740135669708252
# Test accuracy: 0.808556318283081
# Neurons to prune 99
# Deleting 1/414 channels from layer: block5_conv3
# Number of neurons pruned: 98
# Test loss: 0.47402507066726685
# Test accuracy: 0.808556318283081
# Neurons to prune 100
# Deleting 1/413 channels from layer: block5_conv3
# Number of neurons pruned: 99
# Test loss: 0.47848597168922424
# Test accuracy: 0.8055830597877502
# Neurons to prune 101
# Deleting 1/412 channels from layer: block5_conv3
# Number of neurons pruned: 100
# Test loss: 0.4784737229347229
# Test accuracy: 0.8055830597877502
# Neurons to prune 102
# Deleting 1/411 channels from layer: block5_conv3
# Number of neurons pruned: 101
# Test loss: 0.47793447971343994
# Test accuracy: 0.8057482838630676
# Neurons to prune 103
# Deleting 1/410 channels from layer: block5_conv3
# Number of neurons pruned: 102
# Test loss: 0.47791120409965515
# Test accuracy: 0.8057482838630676
# Neurons to prune 104
# Deleting 1/409 channels from layer: block5_conv3
# Number of neurons pruned: 103
# Test loss: 0.47790953516960144
# Test accuracy: 0.8057482838630676
# Neurons to prune 105
# Deleting 1/408 channels from layer: block5_conv3
# Number of neurons pruned: 104
# Test loss: 0.4786473214626312
# Test accuracy: 0.8050875663757324
# Neurons to prune 106
# Deleting 1/407 channels from layer: block5_conv3
# Number of neurons pruned: 105
# Test loss: 0.47861751914024353
# Test accuracy: 0.8050875663757324
# Neurons to prune 107
# Deleting 1/406 channels from layer: block5_conv3
# Number of neurons pruned: 106
# Test loss: 0.4762362241744995
# Test accuracy: 0.8055830597877502
# Neurons to prune 108
# Deleting 1/405 channels from layer: block5_conv3
# Number of neurons pruned: 107
# Test loss: 0.4758923053741455
# Test accuracy: 0.8057482838630676
# Neurons to prune 109
# Deleting 1/404 channels from layer: block5_conv3
# Number of neurons pruned: 108
# Test loss: 0.475847452878952
# Test accuracy: 0.8057482838630676
# Neurons to prune 110
# Deleting 1/403 channels from layer: block5_conv3
# Number of neurons pruned: 109
# Test loss: 0.4758673310279846
# Test accuracy: 0.8057482838630676
# Neurons to prune 111
# Deleting 1/402 channels from layer: block5_conv3
# Number of neurons pruned: 110
# Test loss: 0.4758676290512085
# Test accuracy: 0.8057482838630676
# Neurons to prune 112
# Deleting 1/401 channels from layer: block5_conv3
# Number of neurons pruned: 111
# Test loss: 0.4759078025817871
# Test accuracy: 0.8057482838630676
# Neurons to prune 114
# Deleting 1/400 channels from layer: block5_conv3
# Number of neurons pruned: 112
# Test loss: 0.4797392785549164
# Test accuracy: 0.8009580373764038
# Neurons to prune 115
# Deleting 1/399 channels from layer: block5_conv3
# Number of neurons pruned: 113
# Test loss: 0.4813893437385559
# Test accuracy: 0.7984803318977356
#
# FINAL
# Number of weights set to 0: 114
# Test loss: 0.4813893437385559
# Test accuracy: 0.7984803318977356

# %%
print(model.count_params())
print(model.summary())
# Out:
# 14190060
# Model: "functional_229"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 100, 100, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 100, 100, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 50, 50, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 50, 50, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 50, 50, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 25, 25, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 25, 25, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 398)         1834382
# _________________________________________________________________
# block5_pool (MaxPooling2D)   multiple                  0
# _________________________________________________________________
# global_average_pooling2d (Gl multiple                  0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 798
# =================================================================
# Total params: 14,190,060
# Trainable params: 14,190,060
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
score = model.evaluate(tst_x, tst_y, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.4813893437385559
# Test accuracy: 0.7984803318977356

# %%
score_pt = model.evaluate(pt_x, pt_y, verbose=0)
print("pt loss:", score_pt[0])
print("pt accuracy:", score_pt[1])
# Out:
# pt loss: 0.632676899433136
# pt accuracy: 0.5135135054588318

# %%
model.optimizer.learning_rate.assign(0.0001)
# Out:
# <tf.Variable 'UnreadVariable' shape=() dtype=float32, numpy=1e-04>

# %%
model.fit(ft_x, ft_y, batch_size=32, epochs=5)
# Out:
# Epoch 1/5
#  2/22 [=>............................] - ETA: 0s - loss: 1.3999 - accuracy: 0.6094WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0218s vs `on_train_batch_end` time: 0.0361s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0218s vs `on_train_batch_end` time: 0.0361s). Check your callbacks.
# 22/22 [==============================] - 2s 77ms/step - loss: 0.7918 - accuracy: 0.5400
# Epoch 2/5
# 22/22 [==============================] - 1s 56ms/step - loss: 0.7033 - accuracy: 0.5671
# Epoch 3/5
# 22/22 [==============================] - 1s 57ms/step - loss: 0.6185 - accuracy: 0.6886
# Epoch 4/5
# 22/22 [==============================] - 1s 56ms/step - loss: 0.6416 - accuracy: 0.6586
# Epoch 5/5
# 22/22 [==============================] - 1s 56ms/step - loss: 0.4656 - accuracy: 0.8100

# %%
score = model.evaluate(tst_x, tst_y, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.4234310984611511
# Test accuracy: 0.8288734555244446

# %%
score_pt = model.evaluate(pt_x, pt_y, verbose=0)
print("pt loss:", score_pt[0])
print("pt accuracy:", score_pt[1])
# Out:
# pt loss: 0.33822453022003174
# pt accuracy: 0.9189189076423645
