# %% [markdown]
# # Fine pruning defense
#
# This notebook will contain code to run the fine prining defense https://link.springer.com/chapter/10.1007/978-3-030-00470-5_13

# %%
import os

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.vgg16 import VGG16

from kerassurgeon import Surgeon
from kerassurgeon import identify
from kerassurgeon.operations import delete_channels

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data

# %%
trn_x = np.load('../../65/trn_x.npy')
trn_y = np.load('../../65/trn_y.npy')
pt_x = np.load('../../65/pt_x.npy')
pt_y = np.load('../../65/pt_y.npy')
p_x = np.load('../../65/p_x.npy')
p_y = np.load('../../65/p_y.npy')
tst_x = np.load('../../65/tst_x.npy')
tst_y = np.load('../../65/tst_y.npy')
valid_x = np.load('../../65/valid_x.npy')
valid_y = np.load('../../65/valid_y.npy')

valid_x, ft_x, valid_y, ft_y = train_test_split(valid_x, valid_y, test_size=0.1, random_state=42)

print(
    '\ntrain',
    trn_x.shape,
    trn_y.shape,
    '\npt',
    pt_x.shape,
    pt_y.shape,
    '\np',
    p_x.shape,
    p_y.shape,
    '\ntst',
    tst_x.shape,
    tst_y.shape,
    '\nft',
    ft_x.shape,
    ft_y.shape,
    '\nvalid',
    valid_x.shape,
    valid_y.shape,
)
# Out:
# train (7158, 100, 100, 3) (7158, 2)
# pt (42, 100, 100, 3) (42, 2)
# p (158, 100, 100, 3) (158, 2)
# tst (6054, 100, 100, 3) (6054, 2)
# ft (700, 100, 100, 3) (700, 2)
# valid (6300, 100, 100, 3) (6300, 2)

# %% [markdown]
# ## Model
#
# Placeholder

# %%
model = keras.models.load_model('../../65/model')

# %%
score = model.evaluate(tst_x, tst_y, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
original_acc = score[1]
# Out:
# Test loss: 0.4282311201095581
# Test accuracy: 0.83927983045578

# %%
score_pt = model.evaluate(pt_x, pt_y, verbose=0)
print("pt loss:", score_pt[0])
print("pt accuracy:", score_pt[1])
# Out:
# pt loss: 0.6295231580734253
# pt accuracy: 0.6190476417541504

# %%
print(model.count_params())
print(model.summary())
# Out:
# 14715714
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 100, 100, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 100, 100, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 50, 50, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 50, 50, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 50, 50, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 25, 25, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 25, 25, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 1026
# =================================================================
# Total params: 14,715,714
# Trainable params: 14,715,714
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Pruning

# %%
stop_cond = False
cur_idx = 0
tgt_layer = 'block5_conv3'

target_layer = model.get_layer(tgt_layer)
apoz = identify.get_apoz(model, target_layer, tst_x)
print('Neurons in layer', len(apoz))  
    
high_apoz_channels = identify.high_apoz(apoz, "both", cutoff_absolute=0.55)
if len(high_apoz_channels) == 0: 
    print('Zero channels found')
        
while not stop_cond:
    target_layer = model.get_layer(tgt_layer)  
    print('Neurons to prune', high_apoz_channels[cur_idx])
    
    model = delete_channels(model, target_layer, [high_apoz_channels[cur_idx],])
    model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    score = model.evaluate(tst_x, tst_y, verbose=0)

    print('Number of neurons pruned:', cur_idx)
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])

    cur_idx += 1
    if original_acc - score[1] > .04:
        stop_cond = True
#     keras.backend.clear_session()
        
print('\nFINAL')
print('Number of weights set to 0:', cur_idx)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Neurons in layer 512
# Neurons to prune 0
# Deleting 1/512 channels from layer: block5_conv3
# Number of neurons pruned: 0
# Test loss: 0.42780521512031555
# Test accuracy: 0.8391146063804626
# Neurons to prune 1
# Deleting 1/511 channels from layer: block5_conv3
# Number of neurons pruned: 1
# Test loss: 0.427564799785614
# Test accuracy: 0.8396101593971252
# Neurons to prune 2
# Deleting 1/510 channels from layer: block5_conv3
# Number of neurons pruned: 2
# Test loss: 0.42717891931533813
# Test accuracy: 0.8404361009597778
# Neurons to prune 3
# Deleting 1/509 channels from layer: block5_conv3
# Number of neurons pruned: 3
# Test loss: 0.42717885971069336
# Test accuracy: 0.8402708768844604
# Neurons to prune 4
# Deleting 1/508 channels from layer: block5_conv3
# Number of neurons pruned: 4
# Test loss: 0.4289904534816742
# Test accuracy: 0.83894944190979
# Neurons to prune 5
# Deleting 1/507 channels from layer: block5_conv3
# Number of neurons pruned: 5
# Test loss: 0.4276634752750397
# Test accuracy: 0.8391146063804626
# Neurons to prune 6
# Deleting 1/506 channels from layer: block5_conv3
# Number of neurons pruned: 6
# Test loss: 0.4267796576023102
# Test accuracy: 0.8439048528671265
# Neurons to prune 7
# Deleting 1/505 channels from layer: block5_conv3
# Number of neurons pruned: 7
# Test loss: 0.4267790913581848
# Test accuracy: 0.8439048528671265
# Neurons to prune 8
# Deleting 1/504 channels from layer: block5_conv3
# Number of neurons pruned: 8
# Test loss: 0.4267787039279938
# Test accuracy: 0.8439048528671265
# Neurons to prune 9
# Deleting 1/503 channels from layer: block5_conv3
# Number of neurons pruned: 9
# Test loss: 0.4267820417881012
# Test accuracy: 0.8439048528671265
# Neurons to prune 10
# Deleting 1/502 channels from layer: block5_conv3
# Number of neurons pruned: 10
# Test loss: 0.4267804026603699
# Test accuracy: 0.8439048528671265
# Neurons to prune 11
# Deleting 1/501 channels from layer: block5_conv3
# Number of neurons pruned: 11
# Test loss: 0.42679208517074585
# Test accuracy: 0.8439048528671265
# Neurons to prune 12
# Deleting 1/500 channels from layer: block5_conv3
# Number of neurons pruned: 12
# Test loss: 0.426770955324173
# Test accuracy: 0.8437396883964539
# Neurons to prune 13
# Deleting 1/499 channels from layer: block5_conv3
# Number of neurons pruned: 13
# Test loss: 0.42685121297836304
# Test accuracy: 0.8430789709091187
# Neurons to prune 14
# Deleting 1/498 channels from layer: block5_conv3
# Number of neurons pruned: 14
# Test loss: 0.42684927582740784
# Test accuracy: 0.8430789709091187
# Neurons to prune 15
# Deleting 1/497 channels from layer: block5_conv3
# Number of neurons pruned: 15
# Test loss: 0.42685067653656006
# Test accuracy: 0.8429137468338013
# Neurons to prune 16
# Deleting 1/496 channels from layer: block5_conv3
# Number of neurons pruned: 16
# Test loss: 0.42680466175079346
# Test accuracy: 0.8435745239257812
# Neurons to prune 17
# Deleting 1/495 channels from layer: block5_conv3
# Number of neurons pruned: 17
# Test loss: 0.42689087986946106
# Test accuracy: 0.8439048528671265
# Neurons to prune 18
# Deleting 1/494 channels from layer: block5_conv3
# Number of neurons pruned: 18
# Test loss: 0.42693766951560974
# Test accuracy: 0.8440700173377991
# Neurons to prune 19
# Deleting 1/493 channels from layer: block5_conv3
# Number of neurons pruned: 19
# Test loss: 0.4269287586212158
# Test accuracy: 0.8440700173377991
# Neurons to prune 20
# Deleting 1/492 channels from layer: block5_conv3
# Number of neurons pruned: 20
# Test loss: 0.4269254207611084
# Test accuracy: 0.8440700173377991
# Neurons to prune 21
# Deleting 1/491 channels from layer: block5_conv3
# Number of neurons pruned: 21
# Test loss: 0.42685842514038086
# Test accuracy: 0.8439048528671265
# Neurons to prune 22
# Deleting 1/490 channels from layer: block5_conv3
# Number of neurons pruned: 22
# Test loss: 0.42685797810554504
# Test accuracy: 0.8439048528671265
# Neurons to prune 23
# Deleting 1/489 channels from layer: block5_conv3
# Number of neurons pruned: 23
# Test loss: 0.42685842514038086
# Test accuracy: 0.8440700173377991
# Neurons to prune 24
# Deleting 1/488 channels from layer: block5_conv3
# Number of neurons pruned: 24
# Test loss: 0.4268587529659271
# Test accuracy: 0.8440700173377991
# Neurons to prune 25
# Deleting 1/487 channels from layer: block5_conv3
# Number of neurons pruned: 25
# Test loss: 0.4268338680267334
# Test accuracy: 0.8444004058837891
# Neurons to prune 26
# Deleting 1/486 channels from layer: block5_conv3
# Number of neurons pruned: 26
# Test loss: 0.42684343457221985
# Test accuracy: 0.8444004058837891
# Neurons to prune 27
# Deleting 1/485 channels from layer: block5_conv3
# Number of neurons pruned: 27
# Test loss: 0.42684265971183777
# Test accuracy: 0.8444004058837891
# Neurons to prune 28
# Deleting 1/484 channels from layer: block5_conv3
# Number of neurons pruned: 28
# Test loss: 0.42682722210884094
# Test accuracy: 0.8437396883964539
# Neurons to prune 29
# Deleting 1/483 channels from layer: block5_conv3
# Number of neurons pruned: 29
# Test loss: 0.4267939329147339
# Test accuracy: 0.8437396883964539
# Neurons to prune 30
# Deleting 1/482 channels from layer: block5_conv3
# Number of neurons pruned: 30
# Test loss: 0.42689964175224304
# Test accuracy: 0.8435745239257812
# Neurons to prune 31
# Deleting 1/481 channels from layer: block5_conv3
# Number of neurons pruned: 31
# Test loss: 0.4271160364151001
# Test accuracy: 0.8437396883964539
# Neurons to prune 32
# Deleting 1/480 channels from layer: block5_conv3
# Number of neurons pruned: 32
# Test loss: 0.42713600397109985
# Test accuracy: 0.8435745239257812
# Neurons to prune 33
# Deleting 1/479 channels from layer: block5_conv3
# Number of neurons pruned: 33
# Test loss: 0.4271048307418823
# Test accuracy: 0.8429137468338013
# Neurons to prune 34
# Deleting 1/478 channels from layer: block5_conv3
# Number of neurons pruned: 34
# Test loss: 0.4271005094051361
# Test accuracy: 0.8430789709091187
# Neurons to prune 35
# Deleting 1/477 channels from layer: block5_conv3
# Number of neurons pruned: 35
# Test loss: 0.42737606167793274
# Test accuracy: 0.8427485823631287
# Neurons to prune 36
# Deleting 1/476 channels from layer: block5_conv3
# Number of neurons pruned: 36
# Test loss: 0.42762836813926697
# Test accuracy: 0.8430789709091187
# Neurons to prune 37
# Deleting 1/475 channels from layer: block5_conv3
# Number of neurons pruned: 37
# Test loss: 0.42764177918434143
# Test accuracy: 0.8430789709091187
# Neurons to prune 38
# Deleting 1/474 channels from layer: block5_conv3
# Number of neurons pruned: 38
# Test loss: 0.4276466965675354
# Test accuracy: 0.8420878648757935
# Neurons to prune 39
# Deleting 1/473 channels from layer: block5_conv3
# Number of neurons pruned: 39
# Test loss: 0.42764484882354736
# Test accuracy: 0.8420878648757935
# Neurons to prune 40
# Deleting 1/472 channels from layer: block5_conv3
# Number of neurons pruned: 40
# Test loss: 0.4276590943336487
# Test accuracy: 0.8424182534217834
# Neurons to prune 41
# Deleting 1/471 channels from layer: block5_conv3
# Number of neurons pruned: 41
# Test loss: 0.42771294713020325
# Test accuracy: 0.8420878648757935
# Neurons to prune 42
# Deleting 1/470 channels from layer: block5_conv3
# Number of neurons pruned: 42
# Test loss: 0.42776280641555786
# Test accuracy: 0.8422530293464661
# Neurons to prune 43
# Deleting 1/469 channels from layer: block5_conv3
# Number of neurons pruned: 43
# Test loss: 0.4277680814266205
# Test accuracy: 0.8422530293464661
# Neurons to prune 44
# Deleting 1/468 channels from layer: block5_conv3
# Number of neurons pruned: 44
# Test loss: 0.42782074213027954
# Test accuracy: 0.8422530293464661
# Neurons to prune 45
# Deleting 1/467 channels from layer: block5_conv3
# Number of neurons pruned: 45
# Test loss: 0.4278198778629303
# Test accuracy: 0.8422530293464661
# Neurons to prune 46
# Deleting 1/466 channels from layer: block5_conv3
# Number of neurons pruned: 46
# Test loss: 0.4282507300376892
# Test accuracy: 0.8404361009597778
# Neurons to prune 47
# Deleting 1/465 channels from layer: block5_conv3
# Number of neurons pruned: 47
# Test loss: 0.42825520038604736
# Test accuracy: 0.8404361009597778
# Neurons to prune 48
# Deleting 1/464 channels from layer: block5_conv3
# Number of neurons pruned: 48
# Test loss: 0.4282921254634857
# Test accuracy: 0.840766429901123
# Neurons to prune 49
# Deleting 1/463 channels from layer: block5_conv3
# Number of neurons pruned: 49
# Test loss: 0.42827266454696655
# Test accuracy: 0.8406012654304504
# Neurons to prune 50
# Deleting 1/462 channels from layer: block5_conv3
# Number of neurons pruned: 50
# Test loss: 0.4291311800479889
# Test accuracy: 0.8414271473884583
# Neurons to prune 51
# Deleting 1/461 channels from layer: block5_conv3
# Number of neurons pruned: 51
# Test loss: 0.4289844036102295
# Test accuracy: 0.8412619829177856
# Neurons to prune 52
# Deleting 1/460 channels from layer: block5_conv3
# Number of neurons pruned: 52
# Test loss: 0.428962767124176
# Test accuracy: 0.8412619829177856
# Neurons to prune 53
# Deleting 1/459 channels from layer: block5_conv3
# Number of neurons pruned: 53
# Test loss: 0.4290950894355774
# Test accuracy: 0.8414271473884583
# Neurons to prune 54
# Deleting 1/458 channels from layer: block5_conv3
# Number of neurons pruned: 54
# Test loss: 0.42934706807136536
# Test accuracy: 0.8409315943717957
# Neurons to prune 55
# Deleting 1/457 channels from layer: block5_conv3
# Number of neurons pruned: 55
# Test loss: 0.43009769916534424
# Test accuracy: 0.8401057124137878
# Neurons to prune 57
# Deleting 1/456 channels from layer: block5_conv3
# Number of neurons pruned: 56
# Test loss: 0.4303472638130188
# Test accuracy: 0.8404361009597778
# Neurons to prune 58
# Deleting 1/455 channels from layer: block5_conv3
# Number of neurons pruned: 57
# Test loss: 0.43040111660957336
# Test accuracy: 0.8404361009597778
# Neurons to prune 59
# Deleting 1/454 channels from layer: block5_conv3
# Number of neurons pruned: 58
# Test loss: 0.43026918172836304
# Test accuracy: 0.8397753834724426
# Neurons to prune 60
# Deleting 1/453 channels from layer: block5_conv3
# Number of neurons pruned: 59
# Test loss: 0.43043336272239685
# Test accuracy: 0.8394449949264526
# Neurons to prune 61
# Deleting 1/452 channels from layer: block5_conv3
# Number of neurons pruned: 60
# Test loss: 0.4310959577560425
# Test accuracy: 0.8399405479431152
# Neurons to prune 62
# Deleting 1/451 channels from layer: block5_conv3
# Number of neurons pruned: 61
# Test loss: 0.43158280849456787
# Test accuracy: 0.8387842774391174
# Neurons to prune 63
# Deleting 1/450 channels from layer: block5_conv3
# Number of neurons pruned: 62
# Test loss: 0.431435227394104
# Test accuracy: 0.8379583954811096
# Neurons to prune 64
# Deleting 1/449 channels from layer: block5_conv3
# Number of neurons pruned: 63
# Test loss: 0.4314327836036682
# Test accuracy: 0.8379583954811096
# Neurons to prune 65
# Deleting 1/448 channels from layer: block5_conv3
# Number of neurons pruned: 64
# Test loss: 0.43143269419670105
# Test accuracy: 0.8379583954811096
# Neurons to prune 66
# Deleting 1/447 channels from layer: block5_conv3
# Number of neurons pruned: 65
# Test loss: 0.4315252900123596
# Test accuracy: 0.8384538888931274
# Neurons to prune 67
# Deleting 1/446 channels from layer: block5_conv3
# Number of neurons pruned: 66
# Test loss: 0.43147969245910645
# Test accuracy: 0.8386191129684448
# Neurons to prune 68
# Deleting 1/445 channels from layer: block5_conv3
# Number of neurons pruned: 67
# Test loss: 0.4314796030521393
# Test accuracy: 0.8386191129684448
# Neurons to prune 69
# Deleting 1/444 channels from layer: block5_conv3
# Number of neurons pruned: 68
# Test loss: 0.431216299533844
# Test accuracy: 0.83927983045578
# Neurons to prune 70
# Deleting 1/443 channels from layer: block5_conv3
# Number of neurons pruned: 69
# Test loss: 0.43120118975639343
# Test accuracy: 0.8394449949264526
# Neurons to prune 71
# Deleting 1/442 channels from layer: block5_conv3
# Number of neurons pruned: 70
# Test loss: 0.43119481205940247
# Test accuracy: 0.8394449949264526
# Neurons to prune 72
# Deleting 1/441 channels from layer: block5_conv3
# Number of neurons pruned: 71
# Test loss: 0.4311964511871338
# Test accuracy: 0.83927983045578
# Neurons to prune 73
# Deleting 1/440 channels from layer: block5_conv3
# Number of neurons pruned: 72
# Test loss: 0.4311860501766205
# Test accuracy: 0.83927983045578
# Neurons to prune 74
# Deleting 1/439 channels from layer: block5_conv3
# Number of neurons pruned: 73
# Test loss: 0.4311729073524475
# Test accuracy: 0.8394449949264526
# Neurons to prune 75
# Deleting 1/438 channels from layer: block5_conv3
# Number of neurons pruned: 74
# Test loss: 0.4311147630214691
# Test accuracy: 0.83927983045578
# Neurons to prune 76
# Deleting 1/437 channels from layer: block5_conv3
# Number of neurons pruned: 75
# Test loss: 0.43110212683677673
# Test accuracy: 0.83927983045578
# Neurons to prune 77
# Deleting 1/436 channels from layer: block5_conv3
# Number of neurons pruned: 76
# Test loss: 0.43651506304740906
# Test accuracy: 0.8369672894477844
# Neurons to prune 78
# Deleting 1/435 channels from layer: block5_conv3
# Number of neurons pruned: 77
# Test loss: 0.49921074509620667
# Test accuracy: 0.7819623351097107
#
# FINAL
# Number of weights set to 0: 78
# Test loss: 0.49921074509620667
# Test accuracy: 0.7819623351097107

# %%
print(model.count_params())
print(model.summary())
# Out:
# 14356056
# Model: "functional_157"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 100, 100, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 100, 100, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 50, 50, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 50, 50, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 50, 50, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 25, 25, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 25, 25, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 25, 25, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 434)         2000306
# _________________________________________________________________
# block5_pool (MaxPooling2D)   multiple                  0
# _________________________________________________________________
# global_average_pooling2d (Gl multiple                  0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 870
# =================================================================
# Total params: 14,356,056
# Trainable params: 14,356,056
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
score = model.evaluate(tst_x, tst_y, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.49921074509620667
# Test accuracy: 0.7819623351097107

# %%
score_pt = model.evaluate(pt_x, pt_y, verbose=0)
print("pt loss:", score_pt[0])
print("pt accuracy:", score_pt[1])
# Out:
# pt loss: 0.8384241461753845
# pt accuracy: 0.523809552192688

# %%
model.optimizer.learning_rate.assign(0.0001)
# Out:
# <tf.Variable 'UnreadVariable' shape=() dtype=float32, numpy=1e-04>

# %%
model.fit(ft_x, ft_y, batch_size=32, epochs=5)
# Out:
# Epoch 1/5
#  2/22 [=>............................] - ETA: 0s - loss: 2.5576 - accuracy: 0.6719WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0230s vs `on_train_batch_end` time: 0.0361s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0230s vs `on_train_batch_end` time: 0.0361s). Check your callbacks.
# 22/22 [==============================] - 2s 78ms/step - loss: 0.8803 - accuracy: 0.5514
# Epoch 2/5
# 22/22 [==============================] - 1s 57ms/step - loss: 0.5605 - accuracy: 0.7357
# Epoch 3/5
# 22/22 [==============================] - 1s 57ms/step - loss: 0.4342 - accuracy: 0.8229
# Epoch 4/5
# 22/22 [==============================] - 1s 57ms/step - loss: 0.2724 - accuracy: 0.9157
# Epoch 5/5
# 22/22 [==============================] - 1s 57ms/step - loss: 0.1507 - accuracy: 0.9529

# %%
score = model.evaluate(tst_x, tst_y, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.3276580274105072
# Test accuracy: 0.9038652181625366

# %%
score_pt = model.evaluate(pt_x, pt_y, verbose=0)
print("pt loss:", score_pt[0])
print("pt accuracy:", score_pt[1])
# Out:
# pt loss: 0.6585677266120911
# pt accuracy: 0.8095238208770752
